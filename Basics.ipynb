# %% [markdown]
# ## Learning Python

# %%
import sys 
import keyword
import operator 
from datetime import datetime
import os

# %% [markdown]
# # Keywords

# %% [markdown]
# ## KeyWords are the reserved words in Python and Can't be used as an identifier

# %%
print(keyword.kwlist)#list of all python keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist) # python Contains 35 Keywords
# Out:
# 35

# %% [markdown]
# # Identifiers

# %% [markdown]
#  ## An Identifier is a name given to entities like class , functions variables , etc . It Helps to differentiate one entity from another

# %%
1var = 10 # Identifier can't start with a digit
# Out:
#   Cell In[5], line 1
#     1var = 10 # Identifier can't start with a digit
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@ = 35 #Identifier can't use special Symbols

# %%
import = 125 # Keywords can't be used as identifier
# Out:
#   Cell In[6], line 1
#     import = 125 # Keywords can't be used as identifier
#            ^
# SyntaxError: invalid syntax

# %%
"""
Correct Way of Defining an Identifier
(identifiers Can be combination of letters in lowercase (a to z) or uprcase (A to Z))
"""
val2 = 10

# %%
val_ = 99

# %% [markdown]
# # Comments in Python

# %% [markdown]
# ## Comments can be used to explain the code for more readability

# %%
#single line comment
val1 = 10

# %%
# multiple 
# line
# comment
val1 = 10

# %%
'''
Multiple 
line 
comment
'''
# Out:
# '\nMultiple \nline \ncomment\n'

# %%
"""
Multiple
line 
comment
"""
# Out:
# '\nMultiple\nline \ncomment\n'

# %% [markdown]
# # Statements

# %% [markdown]
# ## Instruction that a python interpreter can execute

# %%
#single line statement
p1 = 10 + 20
p1
# Out:
# 30

# %%
# single line statement 
p2 = ['a','b','c','d']
p2
# Out:
# ['a', 'b', 'c', 'd']

# %%
# Multiple line statment
p1 = 20 + 30 \
+ 40 + 50 + \
+70 + 80 
p1
# Out:
# 290

# %%
# Multiple line statement
p2 = ['a' ,
'b' ,
'c' ,
'd'
]
p2
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# # Indentation

# %% [markdown]
# ## Indentation refers to the spaces at the beginning of a code line. It is very important as python uses indentation to indicae a block of code. If the indentation is not correct we will endup with **IndentationError** error.

# %%
p = 10 
if p == 10:
    print('P is Equal to 10')#correct indentation
# Out:
# P is Equal to 10

# %%
#if indentation is skipped we wull encounter "IdentationError: expected an indented block
p = 10 
if p == 10:
print('P is equal to 10')
# Out:
#   Cell In[26], line 4
#     print('P is equal to 10')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
for i in range(0,5):
    print(i) # correct indentation
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#if indentation is skipped we wull encounter "IdentationError: expected an indented block
for i in range(0,5):
print(i)
# Out:
#   Cell In[28], line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
for i in range(0,5): print(i) # correct indentation but less readable
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
j=20
for i in range(0,5):
    print(i) # inside the for loop
print(j) # outside the for loop
# Out:
# 0
# 1
# 2
# 3
# 4
# 20

# %% [markdown]
# # Docstrings

# %% [markdown]
# ## 1) Docstrings provide a convenient way of associating documentation with function , classes , methods or modules <br>
# ## 2) They apear right after the defination of a function , method , class or module

# %%
def square(num):
    '''Square Function :- This function will return the square of a number'''
    return num**num

# %%
square(5)
# Out:
# 25

# %%
square.__doc__ # We can access the Docstring using __doc__ method
# Out:
# 'Square Function :- This function will return the square of a number'

# %%
def evenodd(num):
    '''evenodd Function :- This function will test whether a numbr is Even or Odd'''
    if num % 2 == 0:
        print("Even Number")
    else:
        print("Odd Number")

# %%
evenodd(2)
# Out:
# Even Number

# %%
evenodd(3)
# Out:
# Odd Number

# %%
evenodd.__doc__
# Out:
# 'evenodd Function :- This function will test whether a numbr is Even or Odd'
